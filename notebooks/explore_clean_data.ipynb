# %%
from pandas import read_csv

# %%
meta = read_csv("../data/household_tenure_metadata.csv")
med_income = read_csv("../data/median_income_by_race.csv")

# %%
map_to_descriptions = dict(zip(meta["label"], meta["description"]))

# %%
med_income = med_income.rename(columns=map_to_descriptions)

# %%
med_income
# Out:
#                         Year              Virginia Locality  B19013_001E  \
# 0     01/01/2010 12:00:00 AM      Accomack County, Virginia        41372
# 1     01/01/2010 12:00:00 AM     Albemarle County, Virginia        64847
# 2     01/01/2010 12:00:00 AM     Alleghany County, Virginia        43160
# 3     01/01/2010 12:00:00 AM        Amelia County, Virginia        50135
# 4     01/01/2010 12:00:00 AM       Amherst County, Virginia        44757
# ...                      ...                            ...          ...
# 1063  01/01/2014 12:00:00 AM         Suffolk city, Virginia        66822
# 1064  01/01/2014 12:00:00 AM  Virginia Beach city, Virginia        67001
# 1065  01/01/2014 12:00:00 AM      Waynesboro city, Virginia        45499
# 1066  01/01/2014 12:00:00 AM    Williamsburg city, Virginia        48057
# 1067  01/01/2014 12:00:00 AM      Winchester city, Virginia        44731
#
#        B19013A_001E   B19013B_001E   B19013C_001E   B19013D_001E  \
# ...

# %%
tenure = read_csv("../data/tenure_households_by_race.csv")

# %%
meta
# Out:
#           column       type         label  \
# 0           year  timestamp          year
# 1         county       text        county
# 2    B25003_001E    numeric   B25003_001E
# 3    B25003_002E    numeric   B25003_002E
# 4   B25003A_002E    numeric  B25003A_002E
# 5   B25003B_002E    numeric  B25003B_002E
# 6   B25003C_002E    numeric  B25003C_002E
# 7   B25003D_002E    numeric  B25003D_002E
# 8   B25003E_002E    numeric  B25003E_002E
# 9   B25003F_002E    numeric  B25003F_002E
# 10  B25003G_002E    numeric  B25003G_002E
# 11  B25003H_002E    numeric  B25003H_002E
# 12  B25003I_002E    numeric  B25003I_002E
# 13         state       text         state
# 14      county 1       text      county 1
#
#                                           description
# 0                                                Year
# 1                                   Virginia Locality
# 2                          Total number of households
# 3           Total number of owner-occupied households
# ...

# %%
map_to_descriptions = dict(zip(meta["label"], meta["description"]))
tenure = tenure.rename(columns=map_to_descriptions)

# %%
tenure
# Out:
#                         Year               Virginia Locality  \
# 0     01/01/2011 12:00:00 AM      Dickenson County, Virginia
# 1     01/01/2011 12:00:00 AM      Dinwiddie County, Virginia
# 2     01/01/2011 12:00:00 AM          Essex County, Virginia
# 3     01/01/2011 12:00:00 AM        Fairfax County, Virginia
# 4     01/01/2011 12:00:00 AM       Fauquier County, Virginia
# ...                      ...                             ...
# 1196  01/01/2016 12:00:00 AM        Patrick County, Virginia
# 1197  01/01/2016 12:00:00 AM   Pittsylvania County, Virginia
# 1198  01/01/2016 12:00:00 AM       Powhatan County, Virginia
# 1199  01/01/2016 12:00:00 AM  Prince Edward County, Virginia
# 1200  01/01/2016 12:00:00 AM  Prince George County, Virginia
#
#       Total number of households  Total number of owner-occupied households  \
# 0                           6183                                       4835
# 1                           9598                                       7442
# ...
